# %%
import sys
# !{sys.executable} -m pip install gdown
import gdown, pickle
import numpy as np
gdown.download(
id="1HHSZT3lc_MdR3etqQdfUrrWVM5NLctJz",
output="problem_data.pkl",
quiet=False,
)
with open("problem_data.pkl", "rb") as f:
     problem_data = pickle.load(f)
receiver_data = problem_data["receiver_data"] # (Time x Receivers)
receiver_coords = problem_data["receiver_coords"] # (Receivers x 2) [x, z]
dt = problem_data["dt"] # Sampling interval

# %%
import matplotlib.pyplot as plt
plt.imshow(receiver_data)
